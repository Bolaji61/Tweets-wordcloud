# %% [markdown]
# # Understanding Text Data
# - Analyzing Sentiments from Twitter data
# - Generate word frequencies
# - Create Word Clouds in Python
#
# These will give a better overall understanding of the dataset.

# %%
import pandas as pd 
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from wordcloud import STOPWORDS

# %%
#Load the dataset
dataset = pd.read_csv('tweets.csv', encoding = 'ISO-8859-1')
dataset.head()
# Out:
#    Unnamed: 0  X                                               text  \
# 0           1  1  RT @rssurjewala: Critical question: Was PayTM ...
# 1           2  2  RT @Hemant_80: Did you vote on #Demonetization...
# 2           3  3  RT @roshankar: Former FinSec, RBI Dy Governor,...
# 3           4  4  RT @ANI_news: Gurugram (Haryana): Post office ...
# 4           5  5  RT @satishacharya: Reddy Wedding! @mail_today ...
#
#    favorited  favoriteCount replyToSN              created  truncated  \
# 0      False              0       NaN  2016-11-23 18:40:30      False
# 1      False              0       NaN  2016-11-23 18:40:29      False
# 2      False              0       NaN  2016-11-23 18:40:03      False
# 3      False              0       NaN  2016-11-23 18:39:59      False
# 4      False              0       NaN  2016-11-23 18:39:39      False
#
#    replyToSID            id  replyToUID  \
# 0         NaN  8.014957e+17         NaN
# 1         NaN  8.014957e+17         NaN
# ...

# %% [markdown]
# ## Generating a frequency table of all the words present in all the tweets combined

# %%
dataset.text.str

# %%
def gen_freq(text):
    #Will store the list of words
    word_list = []

    #Loop over all the tweets and extract words into word_list
    for tw_words in text.split():
        word_list.extend(tw_words)

    #Create word frequencies using word_list
    word_freq = pd.Series(word_list).value_counts()

    #Print top 20 words
    word_freq[:20]
    
    return word_freq

gen_freq(dataset.text.str)
# Out:
# RT                         11053
# to                          7650
# is                          5152
# in                          4491
# the                         4331
# of                          4053
# #Demonetization             3253
# demonetization              3162
# on                          2751
# #demonetization             2474
# PM                          2384
# Modi                        2379
# India                       2243
# and                         2220
# a                           2180
# that                        2168
# out                         1729
# for                         1672
# so                          1599
# had                         1598
# who                         1591
# Narendra                    1564
# by                          1488
# rich                        1477
# find                        1421
# Dear                        1407
# implement                   1399
# actually                    1370
# ...

# %% [markdown]
# ### Exploratory Data Analysis using Word Clouds
# Install wordcloud using `!pip install wordcloud`

# %%
word_freq = gen_freq(dataset.text.str)
#Generate word cloud
wc = WordCloud(width=400, height=330, max_words=100, background_color='white').generate_from_frequencies(word_freq)

plt.figure(figsize=(12, 8))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# Inferences:
#
# - There is noise in the form of "RT" and "&amp" which can be removed from the word frequency.
# - Stop words like "the", "in", "to", "of" etc. are obviously ranking among the top frequency words but these are just constructs of the English language and are not specific to the people's tweets.
# - Words like "demonetization" have occured multiple times. The reason for this is that the current text is not Normalized so words like "demonetization", "Demonetization" etc. are all considered as different words.
#
# ### Text Cleaning using Regex

# %%
import re

def clean_text(text):
    #Remove RT
    text = re.sub(r'RT', '', text)
    
    #Fix &
    text = re.sub(r'&amp;', '&', text)
    
    #Remove punctuations
    text = re.sub(r'[?!.;:,#@-]', '', text)

    #Convert to lowercase to maintain consistency
    text = text.lower()
    return text

# %% [markdown]
# ### Stop words removal

# %%
#list of inbuilt stopwords in wordcloud
print(STOPWORDS)
# Out:
# {'these', "you've", 'there', "why's", 'between', 'just', 'she', "she's", 'like', 'whom', 'all', 'most', 'been', "doesn't", 'out', "here's", 'could', "i've", 'through', 'be', "couldn't", 'of', 'because', 'ourselves', 'i', "they'll", 'otherwise', 'own', 'doing', 'each', "wasn't", 'again', "hasn't", 'this', "he'd", 'some', "we'll", "she'll", "we'd", "when's", 'a', 'on', 'from', 'herself', 'has', 'have', "we're", 'being', 'else', 'with', 'shall', 'com', 'over', 'them', "it's", 'me', 'where', "won't", 'should', "he's", "shan't", 'yourselves', "you're", 'does', 'were', "she'd", 'why', 'himself', 'theirs', "they'd", 'such', 'they', 'hers', 'him', "how's", "he'll", 'was', 'to', "we've", 'also', 'any', 'in', 'we', 'before', 'until', 'into', 'how', 'its', "they've", 'hence', "who's", 'which', 'during', 'had', 'my', "hadn't", 'as', 'ought', 'yours', 'off', "what's", 'or', 'other', 'our', "that's", 'and', 'but', "didn't", "let's", 'themselves', 'do', 'then', "you'll", 'not', 'after', 'no', 'abov
# ...

# %% [markdown]
# ### Creating a noise-reduced wordcloud

# %%
text = dataset.text.apply(lambda x: clean_text(x))
word_freq = gen_freq(text.str)*100
word_freq = word_freq.drop(labels=STOPWORDS, errors='ignore')

#Generate word cloud
wc = WordCloud(width=450, height=330, max_words=200, background_color='white').generate_from_frequencies(word_freq)

plt.figure(figsize=(12, 14))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
word_freq.head(10)
# Out:
# demonetization    1387200
# india              275200
# modi               274800
# pm                 272900
# narendra           156600
# rich               150900
# find               142200
# dear               141000
# implement          139900
# evanspiegel        138800
# dtype: int64

# %%
text.head()
# Out:
# 0     rssurjewala critical question was paytm infor...
# 1     hemant_80 did you vote on demonetization on m...
# 2     roshankar former finsec rbi dy governor cbdt ...
# 3     ani_news gurugram (haryana) post office emplo...
# 4     satishacharya reddy wedding mail_today cartoo...
# Name: text, dtype: object

# %% [markdown]
# ### Inferences
# - People are talking about govt. policies like demonetization, J&K.
# - There are some personalities that are mentioned numerous times like evanspiegel, PM Narendra Modi, Dr Kumar Vishwas etc.
# - There are also talks about oscars, youtube and terrorists
# - There are many sub-topics that revolve around demonetization like atms, bank, cash, paytm etc. Which tells that many people are concerned about it.
